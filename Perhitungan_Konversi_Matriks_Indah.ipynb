# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

img_path = 'indah.jpg'
img = cv2.imread(img_path)
print(img.shape)

plt.imshow(img)

fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(fix_img)

R, G, B = fix_img[:,:,0], fix_img[:,:,1], fix_img[:,:,2]
print(np.array(fix_img))
# Out:
# (1600, 1200, 3)
# [[[162 119  85]
#   [162 119  85]
#   [161 118  84]
#   ...
#   [127 138 158]
#   [129 137 156]
#   [128 136 155]]
#
#  [[160 117  83]
#   [160 117  83]
#   [160 117  83]
#   ...
#   [127 140 159]
#   [128 139 159]
#   [127 138 156]]
#
#  [[156 116  81]
#   [156 116  81]
#   [156 116  81]
#   ...
#   [126 141 162]
#   [126 141 162]
#   [126 141 160]]
#
#  ...
#
#  [[116 114 138]
#   [110 108 130]
#   [104 102 124]
#   ...
#   [130 131 126]
#   [148 151 144]
#   [163 166 159]]
#
#  [[118 115 142]
#   [116 114 138]
#   [112 110 134]
#   ...
#   [126 128 123]
#   [144 146 141]
#   [158 160 155]]
#
#  [[118 115 142]
#   [120 117 144]
#   [118 115 142]
#   ...
#   [124 126 121]
#   [141 143 138]
#   [155 157 152]]]

# %%
fix_img[:] = np.max(fix_img, axis = -1, keepdims = 1)/2 + np.min(fix_img, axis = -1, keepdims = 1)/2

print(np.array(fix_img[:]))
plt.axis('off')
plt.imshow(fix_img[:])
plt.savefig('metode lightness.jpg', bbox_inches='tight')
# Out:
# [[[123 123 123]
#   [123 123 123]
#   [122 122 122]
#   ...
#   [142 142 142]
#   [142 142 142]
#   [141 141 141]]
#
#  [[121 121 121]
#   [121 121 121]
#   [121 121 121]
#   ...
#   [143 143 143]
#   [143 143 143]
#   [141 141 141]]
#
#  [[118 118 118]
#   [118 118 118]
#   [118 118 118]
#   ...
#   [144 144 144]
#   [144 144 144]
#   [143 143 143]]
#
#  ...
#
#  [[126 126 126]
#   [119 119 119]
#   [113 113 113]
#   ...
#   [128 128 128]
#   [147 147 147]
#   [162 162 162]]
#
#  [[128 128 128]
#   [126 126 126]
#   [122 122 122]
#   ...
#   [125 125 125]
#   [143 143 143]
#   [157 157 157]]
#
#  [[128 128 128]
#   [130 130 130]
#   [128 128 128]
#   ...
#   [123 123 123]
#   [140 140 140]
#   [154 154 154]]]

# %%
gray_img = np.mean(fix_img, axis = 2)
print(np.array(gray_img))

plt.axis('off')
plt.imshow(gray_img, cmap = 'gray')
plt.savefig('Metode Average', bbox_inches = 'tight')
# Out:
# [[122.         122.         121.         ... 141.         140.66666667
#   139.66666667]
#  [120.         120.         120.         ... 142.         142.
#   140.33333333]
#  [117.66666667 117.66666667 117.66666667 ... 143.         143.
#   142.33333333]
#  ...
#  [122.66666667 116.         110.         ... 129.         147.66666667
#   162.66666667]
#  [125.         122.66666667 118.66666667 ... 125.66666667 143.66666667
#   157.66666667]
#  [125.         127.         125.         ... 123.66666667 140.66666667
#   154.66666667]]

# %%
lumi_img = (0.2126*R) + (0.7152*G) + (0.0722*B)
print(lumi_img)

plt.axis('off')
plt.imshow(lumi_img)
plt.savefig('Metode Luminosity.jpg', bbox_inches = 'tight')
# Out:
# [[125.687  125.687  124.687  ... 137.1054 136.671  135.671 ]
#  [123.687  123.687  123.687  ... 138.608  138.1054 136.961 ]
#  [121.977  121.977  121.977  ... 139.3272 139.3272 139.1828]
#  ...
#  [116.158  110.0136 104.0136 ... 130.4264 149.8568 164.8568]
#  [117.5872 116.158  112.158  ... 127.2138 145.2138 159.2138]
#  [117.5872 119.5872 117.5872 ... 125.2138 142.2138 156.2138]]

# %%
wavr_img = (0.299*R) + (0.587*G) + (0.114*B)
print(wavr_img)

plt.axis('off')
plt.imshow(wavr_img, cmap = 'gray')
plt.savefig('Metode Weighted Average.jpg', bbox_inches = 'tight')
# Out:
# [[127.981 127.981 126.981 ... 136.991 136.774 135.774]
#  [125.981 125.981 125.981 ... 138.279 137.991 136.763]
#  [123.97  123.97  123.97  ... 138.909 138.909 138.681]
#  ...
#  [117.334 111.106 105.106 ... 130.131 149.305 164.305]
#  [118.975 117.334 113.334 ... 126.832 144.832 158.832]
#  [118.975 120.975 118.975 ... 124.832 141.832 155.832]]
